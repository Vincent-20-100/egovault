# %% [markdown]
# # EgoVault End-to-End Cognitive Explorer Demo
#
# This notebook presents the **complete product showcase** of EgoVault's 3-Tier Cognitive Memory Engine, moving sequentially from raw document ingestion to intelligence synthesis and verbatim proof.
#
# ### Sequential Journey:
# 1. **Ingestion (Tier 1 Hippocampal Chunks):** Mechanical chunking of PDF source text into verbatim evidence.
# 2. **Semantic Nucleus Segmentation:** Automatic TextTiling segmentation into candidate topics.
# 3. **Obsidian Note Compilation (Tier 2 Neocortical Notes):** Atomic lock claiming and Markdown synthesis.
# 4. **Human Review Lifecycle:** Flipping note review status (`unreviewed` $\to$ `reviewed`).
# 5. **Prefrontal Working Memory Recall (`curate()`):** Context retrieval weighted by note confidence.
# 6. **Verbatim Proof Drill-Down:** Pinpoint evidence lookup via `get_chunks()` with page & line locators.
# 7. **Visual Dashboard:** Pipeline flow metrics, confidence charts, and embedding space topology.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from core.config import load_settings
from infrastructure.context import build_context
from notebooks._lib.embedding_cache import probe_provider

settings = load_settings()
ctx = build_context(settings)
probe_provider(ctx)
print("✓ Provider initialized for End-to-End Cognitive Explorer.")
# Out:
# ✓ Provider initialized for End-to-End Cognitive Explorer.

# %% [markdown]
# ## Complete Cognitive Lifecycle Walkthrough
#
# Run the full pipeline end-to-end on the *Marcus Aurelius Meditations* corpus.

# %%
from notebooks.demo_cognitive_explorer_demo import main as run_explorer_demo
run_explorer_demo()
# Out:
# ...
#   EGOVAULT END-TO-END COGNITIVE EXPLORER DEMO (PRODUCT SHOWCASE)
# ...
#
# [Step 1: Ingestion] Ingesting Marcus-Aurelius-Meditations.pdf (128 pages)...
#          Source UID : 3a9c9eba-81cb-489b-81c1-cf2390752787
#          Status     : rag_ready
#
# [Step 2: Segmentation] Reading segmented note_candidates queue...
#          Chunks     : 293
#          Total candidates generated: 26
#          - Candidate #1 (UID: 5d204112...): "Marcus Aurelius' Meditations - tr. Casaubon v. 8.16,..." (11 chunks)
#          - Candidate #2 (UID: 0290a976...): "ing from truth. Ideas and inferences artificially produ..." (40 chunks)
#          - Candidate #3 (UID: 00c4b215...): "the deaths of divers, were afterwards them- selves..." (11 chunks)
#          - Candidate #4 (UID: 36292bfc...): "a man must pass pure, ever ready to..." (10 chunks)
#          - Candidate #5 (UID: f70228f8...): "crease. O Nature! from thee are all things,..." (3 chunks)
#
# [Step 3: Synthesis Claim] Claiming lock on Candidate #1...
# ...
